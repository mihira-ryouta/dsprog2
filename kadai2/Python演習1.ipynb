# %% [markdown]
# # Python演習課題1

# %% [markdown]
# ## 課題1

# %% [markdown]
# ### 問1
#
# 文字列"datascience"の文字を逆に（末尾から先頭に向かって）並べた文字列を出力してください

# %%
X = "datascience"
sakasa = X[::-1] # 文字列を逆順にスライス
print(sakasa)
# Out:
# ecneicsatad

# %% [markdown]
# ### 問2
#
# 「ヘエルスシトンニキア」という文字列の1,3,5,7,9文字目を取り出して連結した文字列を出力してください

# %%
X = "ヘエルスシトンニキア"
extraction = X[1::2] # インデックス1から2つおきに文字を抽出
print(extraction)
# Out:
# エストニア

# %% [markdown]
# ### 問3
#
# 「ヘルシンキ」＋「エストニア」の文字を先頭から交互に連結して文字列「ヘエルスシトンニキア」を出力してください

# %%
X = "ヘルシンキ"
Y = "エストニア"

Z = ""
max_len = max(len(X), len(Y)) #最大の長さを取得
for i in range(max_len): #長い方の長さまでループ
    Z += X[i] + Y[i] #インデックスiの文字を交互に追加

print(Z)
# Out:
# ヘエルスシトンニキア

# %% [markdown]
# ### 問4
#
# "Character education based on the fundamental spirit of Buddhism and the Shiguzeigan"という文を単語に分解し，各単語の（アルファベットの）文字数を先頭から出現順に並べたリストを作成してください

# %%
X = "Character education based on the fundamental spirit of Buddhism and the Shiguzeigan"
words = X.split() # split()メソッドで単語に分割
print((words))
# Out:
# ['Character', 'education', 'based', 'on', 'the', 'fundamental', 'spirit', 'of', 'Buddhism', 'and', 'the', 'Shiguzeigan']

# %% [markdown]
# ### 問5
#
# "It is not the strongest of the species that survives, nor the most intelligent that survives. It is the one that is most adaptable to change."という文を単語に分解し，1, 2, 5, 6, 8, 9, 16番目の単語の先頭の2文字を取り出し，取り出した文字列から単語の位置（先頭から何番目の単語か）を格納した辞書を作成してください

# %%
X = "It is not the strongest of the species that survives, nor the most intelligent that survives. It is the one that is most adaptable to change."
words = X.split()

Y = [1, 2, 5, 6, 8, 9, 16] #取り出す単語の番号

result = {}
for i in Y:
    word = words[i - 1] #0番目から始まるから-1

    z = word[:2] #最初の2文字
    result[i] = z #辞書に追加

print(result)
# Out:
# {1: 'It', 2: 'is', 5: 'st', 6: 'of', 8: 'sp', 9: 'th', 16: 'su'}
